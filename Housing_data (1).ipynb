# %% [markdown]
# ## **DECISION TREE REGRESSION**

# %% [markdown]
# Problem Statement
# Finding the best price your client can sell their house at. The best guess from a model is one that best generalizes the data.
#
# Data Columns -
#
# - CRIM     per capita crime rate by town
# - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS    proportion of non-retail business acres per town
# - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# - NOX      nitric oxides concentration (parts per 10 million)
# - RM       average number of rooms per dwelling
# - AGE      proportion of owner-occupied units built prior to 1940
# - DIS      weighted distances to five Boston employment centres
# - RAD      index of accessibility to radial highways
# - TAX      full-value property-tax rate per $10,000
# - PTRATIO  pupil-teacher ratio by town
# - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#  LSTAT    % lower status of the population
# - MEDV     Median value of owner-occupied homes in 1000 dollers

# %%
## importing the libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
#reading the data
data = pd.read_csv('/content/HousingData.csv')

# %%
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
data.shape
# Out:
# (506, 14)

# %%
## finding the datatypes
data.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
#finding the null values
data.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
## Seperating the numerical columns
num_col = data.select_dtypes(include=['float64','int64']).columns

# %%
## imputing  the numerical columns with mean 
data1 = data[num_col].fillna(data[num_col].mean())

# %%
data1.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
## Finding the summary Statistics
data1.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.545770   22.921051    6.699165    0.250233    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.083235    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.290250    0.000000    9.900000    0.000000    0.538000    6.208500
# 75%      3.611874   11.211934   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# finding the normal distribution
for i in num_col:
  sns.distplot(data1[i])
  plt.show()
# Out:
# <ipython-input-11-2d73f8c8415d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1[i])
# <ipython-input-11-2d73f8c8415d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1[i])
# <ipython-input-11-2d73f8c8415d>:2: UserWarning:
#
# ...

# %%
num_col = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT', 'MEDV']

# %%
## finding the correlation 
data1.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.182930  0.391161 -0.052223  0.410377 -0.215434  0.344934
# ZN      -0.182930  1.000000 -0.513336 -0.036147 -0.502287  0.316550 -0.541274
# INDUS    0.391161 -0.513336  1.000000  0.058035  0.740965 -0.381457  0.614592
# CHAS    -0.052223 -0.036147  0.058035  1.000000  0.073286  0.102284  0.075206
# NOX      0.410377 -0.502287  0.740965  0.073286  1.000000 -0.302188  0.711461
# RM      -0.215434  0.316550 -0.381457  0.102284 -0.302188  1.000000 -0.241351
# AGE      0.344934 -0.541274  0.614592  0.075206  0.711461 -0.241351  1.000000
# DIS     -0.366523  0.638388 -0.699639 -0.091680 -0.769230  0.205246 -0.724353
# RAD      0.608886 -0.306316  0.593176  0.001425  0.611441 -0.209847  0.449989
# TAX      0.566528 -0.308334  0.716062 -0.031483  0.668023 -0.292048  0.500589
# PTRATIO  0.273384 -0.403085  0.384806 -0.109310  0.188933 -0.355501  0.262723
# ...

# %%
## finding the outliers 
for i in num_col:
  sns.boxplot(data1[i])
  plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
## Standerdizing the data
#scalar = StandardScaler()
#data1[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
 #      'PTRATIO', 'B', 'LSTAT']] = scalar.fit_transform(data1[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
  #     'PTRATIO', 'B', 'LSTAT']])

# %%
data1
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.200000  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.900000  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.100000  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.800000  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.200000  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...        ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.100000  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.700000  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.000000  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.300000  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  68.518519  2.5050    1  273
#
#      PTRATIO       B      LSTAT  MEDV
# ...

# %%
for i in data1:
  sns.distplot(data1[i])
  plt.show()
# Out:
# <ipython-input-18-e6174fd5ade6>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1[i])
# <ipython-input-18-e6174fd5ade6>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1[i])
# <ipython-input-18-e6174fd5ade6>:2: UserWarning:
#
# ...

# %%
# standerdizing the data using RobustScaler
from sklearn.preprocessing import RobustScaler
trans = RobustScaler()
data1[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']] = trans.fit_transform(data1[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']])

# %%
data1
# Out:
#          CRIM        ZN     INDUS  CHAS       NOX        RM       AGE  \
# 0   -0.080464  1.605432 -0.587916   0.0  0.000000  0.496612 -0.194124
# 1   -0.074516  0.000000 -0.219210   0.0 -0.394286  0.287940  0.093389
# 2   -0.074522  0.000000 -0.219210   0.0 -0.394286  1.323171 -0.280168
# 3   -0.073082  0.000000 -0.597986   0.0 -0.457143  1.069783 -0.601259
# 4   -0.062687  0.000000 -0.597986   0.0 -0.457143  1.271680 -0.424974
# ..        ...       ...       ...   ...       ...       ...       ...
# 501 -0.064506  0.000000  0.157242   0.0  0.200000  0.521003 -0.112277
# 502 -0.069426  0.000000  0.157242   0.0  0.200000 -0.119919  0.047219
# 503 -0.065036  0.000000  0.157242   0.0  0.200000  1.039973  0.347324
# 504 -0.051198  0.000000  0.157242   0.0  0.200000  0.793360  0.311647
# 505 -0.068820  0.000000  0.157242   0.0  0.200000 -0.241870 -0.124480
#
#           DIS   RAD       TAX   PTRATIO         B     LSTAT  MEDV
# ...

# %%
for i in num_col:
  sns.distplot(data1[i])
  plt.show()
# Out:
# <ipython-input-21-2d73f8c8415d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1[i])
# <ipython-input-21-2d73f8c8415d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1[i])
# <ipython-input-21-2d73f8c8415d>:2: UserWarning:
#
# ...

# %%
# seperating the target variable from the data and assigining to the 'y'

x=data1.drop('MEDV', axis=1)
y=data1['MEDV']

# %%
#Splitting the data into train and test data
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state = 2)

# %%
x_train.shape
# Out:
# (404, 13)

# %%
# defining the Decision Tree regressor
dtree = DecisionTreeRegressor(max_depth = 8,min_samples_split=2,min_samples_leaf=3,)

# %%
# fitting the train data to the Decision Tree Model
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=3)

# %%
## Predicting the train values

train_pred=dtree.predict(x_train)
test_pred=dtree.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
## finding how the model fitted the data using R-Squared
train_acc =r2_score(y_train, train_pred)
test_acc= r2_score(y_test, test_pred)

# %%
print('train acc :', train_acc)
print('test acc:', test_acc)
# Out:
# train acc : 0.944583594874715
# test acc: 0.435151920402883

# %%
# finding the diffrence in error between train and test data
train_mse1 =mean_squared_error(y_train, train_pred)
test_mse1= mean_squared_error(y_test, test_pred)

# %%
print('train acc :',train_mse1)
print('test acc:', test_mse1)
# Out:
# train acc : 4.686559850533925
# test acc: 47.25501063444819

# %% [markdown]
# As the model is over fitting used the bgging technique

# %%
rand = RandomForestRegressor(max_depth=18,min_samples_leaf=2,min_samples_split=5)

# %%
rand.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=18, min_samples_leaf=2, min_samples_split=5)

# %%
train_pred1=rand.predict(x_train)
test_pred1=rand.predict(x_test)

# %%
train_r2 =r2_score(y_train, train_pred1)
test_r2= r2_score(y_test, test_pred1)

# %%
print('train acc :', train_r2)
print('test acc:', test_r2)
# Out:
# train acc : 0.9661930211167971
# test acc: 0.8604378502310592

# %%
train_mse1 =mean_squared_error(y_train, train_pred1)
test_mse1= mean_squared_error(y_test, test_pred1)

# %%
print('train mse :', train_mse1)
print('test mse:', test_mse1)
# Out:
# train mse : 2.8590528299999036
# test mse: 11.67572504840895

# %%
param_grid = {
    'max_depth': range(1, 5),
    'min_samples_split': [2, 5, 6],
    'min_samples_leaf': [1, 2, 4]
}

# %%
grid_cv = GridSearchCV(rand, param_grid, cv=5)

# %%
grid_cv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestRegressor(max_depth=18, min_samples_leaf=2,
#                                              min_samples_split=5),
#              param_grid={'max_depth': range(1, 5),
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 6]})

# %%
train_p=grid_cv.predict(x_train)
test_p=grid_cv.predict(x_test)

# %%
train_r2 =r2_score(y_train, train_p)
test_r2= r2_score(y_test, test_p)

# %%
print('train acc :', train_r2)
print('test acc:', test_r2)
# Out:
# train acc : 0.9061560787958162
# test acc: 0.8332652745728881

# %%
train_mse1 =mean_squared_error(y_train, train_p)
test_mse1= mean_squared_error(y_test, test_p)

# %%
print('train acc :',train_mse1)
print('test acc:', test_mse1)
# Out:
# train acc : 7.936371050014689
# test acc: 13.948974083101735
